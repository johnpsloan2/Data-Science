# %% [markdown]
# # Aggregates and Groups
#
# 1 - What was the hottest day in our data set? Where was that?
#
# SELECT
#
#     MaxTemperatureF, ZIP
# FROM
#
#     weather
#
# GROUP by 2
#
# ORDER by MaxTemperatureF DESC
#
# Answer: 78 degrees in zip code 95113.
#
#
#
#
# 2 - How many trips started at each station?
#
# SELECT
#
#     trip_id,
#
#     start_station,
#
#     count(*) 'Number of Trips'
#
# FROM
#
#     trips
#
# GROUP by 2
#
# ORDER by 'Number of Trips' DESC
#
#
#
# 3 - What's the shortest trip that happened?
#
# SELECT
#
#     trip_id,
#
#     min(duration) 'duration'
#
# FROM
#
#     trips
#
# GROUP by 1
#
# ORDER by 2
#
# Answer - The shortest trip is 60. Multiple trips have this duration.
#
#
#
#
# 4 - What is the average trip duration, by end station?
#
# SELECT
#
#     end_station,
#
#     avg(duration) 'Average Duration'
#
# FROM
#
#     trips
#
# GROUP by 1
#
# ORDER by 2 DESC
